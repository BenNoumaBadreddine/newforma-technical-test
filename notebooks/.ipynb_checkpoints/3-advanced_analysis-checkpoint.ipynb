# %% [markdown]
# # Advanced data analysis

# %% [markdown]
# ## Load the data

# %%
# %run ./0-loading_the_data_define_variables.ipynb

# %%
df = df[df.apply(is_valid_state, axis=1)]

# Create an instance of the ColumnTypeConverter
converter = ColumnTypeConverter(df)
# Convert the columns to the specified data types
converter.convert_to_int(COLUMNS_CONVERT_TO_INT)
converter.convert_to_float(COLUMNS_CONVERT_TO_FLOAT)
converter.convert_to_datetime(COLUMNS_CONVERT_TO_DATETIME)


print('Done!')
# Out:
# Done!

# %%
df.category.nunique(), df.main_category.nunique(),
# Out:
# (158, 15)

# %% [markdown]
# # Order the data by the frequently used 'main_category' feature

# %% [raw]
# We choose to use main_category instead of category, because it is more general than 'category' and because it has 15 unique values however the 'category' feature has 158 unique values.

# %%
column = 'main_category'

# Group the data by 'main_category' and count the frequency
category_counts = df.groupby('main_category').size().reset_index(name='count')

# Sort the 'main_category' by 'count' in descending order
sorted_main_categories = category_counts.sort_values(by='count', ascending=False)

# Plot the result as a histogram
plt.figure(figsize=(10, 6))
plt.bar(sorted_main_categories['main_category'], sorted_main_categories['count'])
plt.xlabel('Main Category')
plt.ylabel('Count')
plt.title('Main Categories by Frequency of Usage')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conslusion

# %% [raw]
# we notice that the main_category 'film & Video' is the one that has the highest number of projects in the database and the main_category 'Dance' is the one that has the lowest number of projects.

# %% [markdown]
# # Divide the data using the state: successful and failed

# %%
# Filter records or devide it into two datasets: successful and failed projects
successful_projects = df[df['state'] == 'successful']
failed_projects = df[df['state'] == 'failed']

# sort successful_projects by 'main_categories'
successful_main_category_counts = successful_projects[column].value_counts().sort_values(ascending=False)
# sort failed_projects by 'main_categories'
failed_category_counts = failed_projects[column].value_counts().sort_values(ascending=False)

# plot the successful project by main category
plt.figure(figsize=(10, 6))
plt.bar(successful_main_category_counts.index, successful_main_category_counts.values, color='green')
plt.xlabel('Main Category')
plt.ylabel('Count')
plt.title('Successful projects by Frequency of Usage')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# plot the failed project by main category
plt.figure(figsize=(10, 6))
plt.bar(failed_category_counts.index, failed_category_counts.values, color='red')
plt.xlabel('Main Category')
plt.ylabel('Count')
plt.title('Failed projects by Frequency of Usage')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conslusion

# %% [raw]
# we notice that the main_category 'Music' has the highest rate of success compared to the rest of main categories. It has also an important number of failed projects at the same time. In that case, the ratio or the rate of success is the best way to decide if the main_category Music usualy successful or usualy failed.
# In addition, the number of projects within each category is not the same, so the number of successful or failed project will not help a lot to decide which category is the best.
# That is why the percentage of success or failure is the best mnetric to have a reliable insight.

# %% [markdown]
# # What is the percentage of successful and failed projects per main category

# %% [raw]
# The goal of this analysis is to identify the most succesful categories. To do so, we need to calculate the percentage of success of projects sharing the same main_category.

# %%
# Create a dataframe with main_category as index and two columns successful and failed representing the number of projects
category_stats = pd.DataFrame({'Successful': successful_main_category_counts, 'Failed': failed_category_counts})

# Calculate the total number of projects per main_category (sum of successful and failed projects)
category_stats['Total'] = category_stats['Successful'] + category_stats['Failed']

# Calculate the percentage of successful projects for each category
category_stats['Success_percentage'] = (category_stats['Successful'] / category_stats['Total']) * 100
category_stats['Failed_percentage'] = (category_stats['Failed'] / category_stats['Total']) * 100

# Sort the DataFrame by success percentage in descending order
category_stats = category_stats.sort_values(by='Success_percentage', ascending=False)

category_stats
# Out:
#               Successful  Failed  Total  Success_percentage  Failed_percentage
# Dance               2101    1089   3190           65.862069          34.137931
# Theater             5990    3337   9327           64.222151          35.777849
# Comics              4499    3406   7905           56.913346          43.086654
# Music              21763   19193  40956           53.137513          46.862487
# Art                 9654   12092  21746           44.394371          55.605629
# Film & Video       21404   29653  51057           41.921774          58.078226
# Games               9385   13013  22398           41.901063          58.098937
# Design              7959   12039  19998           39.798980          60.201020
# Publishing         10255   19920  30175           33.985087          66.014913
# Photography         2903    5743   8646           33.576220          66.423780
# Food                5256   13602  18858           27.871460          72.128540
# Fashion             4310   11500  15810           27.261227          72.738773
# Crafts              1671    4630   6301           26.519600          73.480400
# Journalism           869    2657   3526           24.645491          75.354509
# Technology          5062   16347  21409           23.644262          76.355738

# %% [markdown]
# ### Conlusion

# %% [raw]
# According to the results presented in the above table, we notice that the main_categories : Dance (66% success rate) and theater (64% success rate) are the most successful main_category.
#
# In the other side, we notice that the main_category : Technology, Journalism, Crafts, Fashion, Food are the most failed projects. They have a failure rate above 72%.
#
# This analysis demonstrate that it is possible to have an idea of the a successful or failed project by knowing the main category. But, this is only for a few main categories. For other it still random status only by knowing the main category e.g: Art (55% success rate) or Film & Video (58% success rate).

# %% [markdown]
# # Average Funding Goal:

# %%
category_stats['average_funding_goal'] = df.groupby('main_category')['goal'].mean()
category_stats#.sort_values(by='average_funding_goal', ascending=False)
# Out:
#               Successful  Failed  Total  Success_percentage  \
# Dance               2101    1089   3190           65.862069
# Theater             5990    3337   9327           64.222151
# Comics              4499    3406   7905           56.913346
# Music              21763   19193  40956           53.137513
# Art                 9654   12092  21746           44.394371
# Film & Video       21404   29653  51057           41.921774
# Games               9385   13013  22398           41.901063
# Design              7959   12039  19998           39.798980
# Publishing         10255   19920  30175           33.985087
# Photography         2903    5743   8646           33.576220
# Food                5256   13602  18858           27.871460
# Fashion             4310   11500  15810           27.261227
# Crafts              1671    4630   6301           26.519600
# Journalism           869    2657   3526           24.645491
# Technology          5062   16347  21409           23.644262
#
#               Failed_percentage  average_funding_goal
# Dance                 34.137931           8243.256520
# Theater               35.777849          22222.441365
# Comics                43.086654          23810.334256
# Music                 46.862487          14351.509693
# Art                   55.605629          36296.018882
# Film & Video          58.078226          67972.655482
# Games                 58.098937          44873.536107
# Design                60.201020          44223.378834
# Publishing            66.014913          18498.866585
# Photography           66.423780          11386.274173
# Food                  72.128540          49212.734822
# Fashion               72.738773          24339.330478
# Crafts                73.480400          10673.817648
# Journalism            75.354509          47121.030899
# Technology            76.355738         112383.325737

# %% [markdown]
# ### Conlusion

# %% [raw]
# According to the table above we conclude that the funding goal expectation of the most successful projects within the category 'Dance' is the lowest average expectation.
#
# The category Technology has the highest failed rate and the highest funding goal expecation.

# %% [markdown]
# # Average Pledged Amount

# %%
category_stats['average_pledged_amount'] = df.groupby('main_category')['pledged'].mean()
category_stats
# Out:
#               Successful  Failed  Total  Success_percentage  \
# Dance               2101    1089   3190           65.862069
# Theater             5990    3337   9327           64.222151
# Comics              4499    3406   7905           56.913346
# Music              21763   19193  40956           53.137513
# Art                 9654   12092  21746           44.394371
# Film & Video       21404   29653  51057           41.921774
# Games               9385   13013  22398           41.901063
# Design              7959   12039  19998           39.798980
# Publishing         10255   19920  30175           33.985087
# Photography         2903    5743   8646           33.576220
# Food                5256   13602  18858           27.871460
# Fashion             4310   11500  15810           27.261227
# Crafts              1671    4630   6301           26.519600
# Journalism           869    2657   3526           24.645491
# Technology          5062   16347  21409           23.644262
#
#               Failed_percentage  average_funding_goal  average_pledged_amount
# Dance                 34.137931           8243.256520             3562.334824
# Theater               35.777849          22222.441365             4111.348771
# Comics                43.086654          23810.334256             7364.436349
# Music                 46.862487          14351.509693             4120.206910
# Art                   55.605629          36296.018882             3441.927552
# Film & Video          58.078226          67972.655482             6715.640893
# Games                 58.098937          44873.536107            24415.580747
# Design                60.201020          44223.378834            27085.728097
# Publishing            66.014913          18498.866585             3611.623139
# Photography           66.423780          11386.274173             3553.122384
# Food                  72.128540          49212.734822             5544.235783
# Fashion               72.738773          24339.330478             6726.507372
# Crafts                73.480400          10673.817648             1745.621062
# Journalism            75.354509          47121.030899             3333.903588
# Technology            76.355738         112383.325737            23544.278956

# %% [markdown]
# ### Conlusion

# %% [raw]
# The most successful main category 'Dance' has a low pledged amount. But, to have a reliable interpretation we need to consider the funding goal at the same time. That is why the ratio between these two features is very important to derive a reliable conslusion.

# %% [markdown]
# # Ratio of the average funding goal to the average amount pledged

# %%
category_stats['avg_goal_to_pledged_ratio'] = category_stats.average_funding_goal / category_stats.average_pledged_amount
category_stats
# Out:
#               Successful  Failed  Total  Success_percentage  \
# Dance               2101    1089   3190           65.862069
# Theater             5990    3337   9327           64.222151
# Comics              4499    3406   7905           56.913346
# Music              21763   19193  40956           53.137513
# Art                 9654   12092  21746           44.394371
# Film & Video       21404   29653  51057           41.921774
# Games               9385   13013  22398           41.901063
# Design              7959   12039  19998           39.798980
# Publishing         10255   19920  30175           33.985087
# Photography         2903    5743   8646           33.576220
# Food                5256   13602  18858           27.871460
# Fashion             4310   11500  15810           27.261227
# Crafts              1671    4630   6301           26.519600
# Journalism           869    2657   3526           24.645491
# Technology          5062   16347  21409           23.644262
#
#               Failed_percentage  average_funding_goal  average_pledged_amount  \
# Dance                 34.137931           8243.256520             3562.334824
# Theater               35.777849          22222.441365             4111.348771
# Comics                43.086654          23810.334256             7364.436349
# Music                 46.862487          14351.509693             4120.206910
# Art                   55.605629          36296.018882             3441.927552
# Film & Video          58.078226          67972.655482             6715.640893
# Games                 58.098937          44873.536107            24415.580747
# Design                60.201020          44223.378834            27085.728097
# Publishing            66.014913          18498.866585             3611.623139
# Photography           66.423780          11386.274173             3553.122384
# Food                  72.128540          49212.734822             5544.235783
# Fashion               72.738773          24339.330478             6726.507372
# Crafts                73.480400          10673.817648             1745.621062
# Journalism            75.354509          47121.030899             3333.903588
# Technology            76.355738         112383.325737            23544.278956
#
#               avg_goal_to_pledged_ratio
# Dance                          2.314004
# Theater                        5.405146
# Comics                         3.233151
# Music                          3.483201
# Art                           10.545259
# Film & Video                  10.121544
# Games                          1.837906
# Design                         1.632719
# Publishing                     5.122037
# Photography                    3.204583
# Food                           8.876378
# Fashion                        3.618420
# Crafts                         6.114625
# Journalism                    14.133891
# Technology                     4.773275

# %% [markdown]
# ### Conlusion

# %% [raw]
# The ratio of average funding goal to the average pledged amount indicates how well projects in each category perform in terms of reaching their financial goals compared to the money people actually contribute.

# %% [markdown]
# # Is the funding goal amount has an impact on the success of the projects

# %%
plt.figure(figsize=(10, 6))
categories = ['Failed projects' for i in range(len(failed_projects.goal.values))] + ['Successful projects' for i in range(len(successful_projects.goal.values))]
sns.boxplot(x=categories, y=np.concatenate((failed_projects.goal.values, successful_projects.goal.values)))
plt.xlabel('Project status')
plt.ylabel('Funding goal')
plt.title('Impact of funding goal on the status of the project')
plt.show()

# %% [markdown]
# ### Conlusion

# %% [raw]
# According to the plot above, we noticed that, oftenly, if the funding goal is high the project fails. This conlusion is true because the success of the project becomes risky when it is very hard to collect the the amount of money from the contributers. Even Contributers, often, will not support a project that necessitate a huge amount of monye to be done.
#
# In addition, all the succcessful project have a low funding goal. We can a categorical variable to represent low or high funding goal and it will help the machine learning model to predict the status of the project.

# %% [markdown]
# # Is the number of backers has an important impact on the success

# %%
plt.figure(figsize=(10, 6))
categories = ['Failed projects' for i in range(len(failed_projects.backers.values))] + ['Successful projects' for i in range(len(successful_projects.backers.values))]
sns.boxplot(x=categories, y=np.concatenate((failed_projects.backers.values, successful_projects.backers.values)))
plt.xlabel('Project status')
plt.ylabel('Number of backers')
plt.title('Impact of number of backers on the status of the project')
plt.show()

# %% [markdown]
# ### Conlusion

# %% [raw]
# According to the plot above, we noticed that, oftenly, if the number of backers is high the project success. This conlusion is true but not always because we can have a high number of backers but they contribute with a low amount of money. At the same time, it is rare if we have a small number of backers aand they contribute with a high amount of monye.
#
#
# In addition, all the failed project have a low number of backers. We can a categorical variable to represent low or high number of backers and it will help the machine learning model to predict the status of the project.

# %% [markdown]
# # Is the project's location has an impact on the success of the project

# %%
failed_project_country_counts = failed_projects['country'].value_counts()
successful_project_country_counts = successful_projects['country'].value_counts()
plt.scatter(x= failed_project_country_counts.index, y=failed_project_country_counts.values)
plt.scatter(x= successful_project_country_counts.index, y=successful_project_country_counts.values, color='green')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
sns.countplot(data=df, x='country', hue=target, palette=theme_colors, ax=axes)
fig.set_size_inches(15, 8)

# %% [markdown]
# ### Conclusion

# %% [raw]
# In our analysis, the United States stands out as the country with the highest number of projects. Additionally, it exhibits both the highest success rates and the highest failure rates. This trend is primarily attributed to the widespread use of the US dollar (USD) as the currency of choice for these projects.
