# %% [markdown]
# # Data exploration and analysis

# %% [markdown]
# ## Load the data

# %%
# %run ./0-loading_the_data_define_variables.ipynb

# %%
df = df[df.apply(is_valid_state, axis=1)]

# Create an instance of the ColumnTypeConverter
converter = ColumnTypeConverter(df)
# Convert the columns to the specified data types
converter.convert_to_int(COLUMNS_CONVERT_TO_INT)
converter.convert_to_float(COLUMNS_CONVERT_TO_FLOAT)
converter.convert_to_datetime(COLUMNS_CONVERT_TO_DATETIME)


print('Done!')
# Out:
# Done!

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ## Dependant variable: The target variable

# %% [markdown]
# ### Check balanced dataset: Frequency of each output

# %%
fig, ax = plt.subplots(ncols=1, figsize=(5, 5))

spaces = (0.05, 0.05)
label_function = lambda val:  f'{val / 100 * len(df):.0f}\n{val:.0f}%'


df.groupby(target).size().plot(kind= "pie", autopct=label_function,
                                           textprops={'fontsize': 20},
                                           ax=ax, colors= theme_colors, ylabel= "",
                                           shadow= True, explode= spaces)
fig.suptitle("Campaigns status distribution: Failed versus succesful", fontsize= 13)
plt.savefig('../images/data_size',  dpi='figure', format=None, metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None
       )
plt.show()

# %% [markdown]
# ### Conclusion

# %% [raw]
# The above chart is called pie plot. Based on that pie plot, we notice that the database is not balanced and there is 40% of successful records with 60% of failed records.
#
# It is recommended to not use the accuracy metric in the case of non balanced database. Instead, we can use the precision, recall or the f1-score.

# %% [markdown]
# # Independant variable

# %% [markdown]
# ### Categorical variables distribution

# %%
from newforma_technical_test.src.visualization_functions import categorical_var_distribution
    
categorical_var_distribution(df, 'category', number_of_bars=50)

# %%
categorical_var_distribution(df,'main_category')

# %%
categorical_var_distribution(df,'country')

# %% [markdown]
# ## Check the existence of outliers:  whisker plots

# %%
numerical_var_distribution(df)
# Out:
# 'goal' distribution:
# 'pledged' distribution:
# 'usd_pledged' distribution:

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The whisker plots for the variables: usd_pledged, goal, and pledged indicate that there are a potential outliers in the dataset. Outlier in our case doesn't mean error in the dataset or wrong records. They are real word case but not very often that happen. As a solution for that we can either remove them from the dataset or minimize these outliers.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Categorical Independent Variable vs Target Variable

# %%
from td_bank_test_scenario.src.util import categorical_variables_versus_target_bins_plot

categorical_variables = ['City', 'Gender', 'PrimaryAcHolder', 'HasOnlineService', 'HasCrCard', 'IsActiveMember', 'Tenure']
categorical_variables_versus_target_bins_plot(df_hackathon_train_main, categorical_variables, target, theme_colors)

# %% [markdown]
# ### Numerical Independent Variable vs Target Variable

# %%
from td_bank_test_scenario.src.util import numerical_variables_versus_target_bins_plot

numerical_variables = ['CreditScore', 'Balance', 'EstimatedSalary'] 
for i, num_var in enumerate(numerical_variables):
    print(f"{PrintStyle.BOLD}{i+1}-Bi-variate Analysis on '{num_var}' variable versus the target '{target}':"
              f"{PrintStyle.END}")
    numerical_variables_versus_target_bins_plot(df_hackathon_train_main, num_var, target, theme_colors)
# Out:
# 1-Bi-variate Analysis on 'CreditScore' variable versus the target 'Exited':
# 2-Bi-variate Analysis on 'Balance' variable versus the target 'Exited':
# 3-Bi-variate Analysis on 'EstimatedSalary' variable versus the target 'Exited':

# %% [markdown]
# ## Correlation matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = categorical_variables+numerical_variables+[target]

matrix = df_hackathon_train_main[features].corr()
f, ax = plt.subplots(figsize=(9,6))
sns.heatmap(matrix,vmax=.8,square=True,cmap="BuPu", annot = True)
# Out:
# <AxesSubplot:>

# %%
categorical_variables = ['City', 'Gender', 'PrimaryAcHolder', 'HasOnlineService', 'HasCrCard', 'IsActiveMember', 'Tenure']

features = categorical_variables+numerical_variables+[target]
theme_colors = ["#ff8533", "#808080"]
df_corr = df_hackathon_train_main[features].apply(lambda x :
    pd.factorize(x)[0]).corr(method='spearman', min_periods=1)

cm = sns.light_palette(theme_colors[1], as_cmap=True)

df = df_corr.style.background_gradient(cmap= cm)

dfi.export(df, '../images/correlation_matrix.png')
df
# Out:
# <style type="text/css">
# #T_7b051_row0_col0, #T_7b051_row1_col1, #T_7b051_row2_col2, #T_7b051_row3_col3, #T_7b051_row4_col4, #T_7b051_row5_col5, #T_7b051_row6_col6, #T_7b051_row7_col7, #T_7b051_row8_col8, #T_7b051_row9_col9, #T_7b051_row10_col10 {
#   background-color: #808080;
#   color: #f1f1f1;
# }
# #T_7b051_row0_col1, #T_7b051_row2_col1, #T_7b051_row4_col1, #T_7b051_row5_col10, #T_7b051_row6_col10, #T_7b051_row10_col6 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_7b051_row0_col2, #T_7b051_row3_col10, #T_7b051_row4_col2, #T_7b051_row5_col3, #T_7b051_row5_col6, #T_7b051_row5_col7, #T_7b051_row5_col8, #T_7b051_row5_col9, #T_7b051_row6_col2, #T_7b051_row8_col0, #T_7b051_row8_col2, #T_7b051_row9_col0, #T_7b051_row9_col1, #T_7b051_row9_col4, #T_7b051_row9_col5 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_7b051_row0_col3, #T_7b051_row2_col3, #T_7b051_row3_col1, #T_7b051_row4_col3 {
#   background-color: #edeeed;
#   color: #000000;
# }
# ...

# %% [markdown]
# **Interpretaion**:
#
# We check for the variables having highest correlation values, and reove them from the list of features. In our case we don't have any variable that has high corelation value.
#
# As an interpretaion for the above correlationmatrix we can conclude that this matrix does't show us a correlation between variables, but this doesn't mean that there is no correlation at all. The metric used in that calculation is a pearson metric. It assess the linear relationship between pairs of variables in a dataset. So, it is possible to have another kind of relationship other than linear (Curvilinear Relationship, non linear, Categorical ...)

# %%
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_a6c6f_row0_col0, #T_a6c6f_row0_col1, #T_a6c6f_row1_col1, #T_a6c6f_row1_col2, #T_a6c6f_row1_col3, #T_a6c6f_row1_col4, #T_a6c6f_row2_col3, #T_a6c6f_row3_col0, #T_a6c6f_row3_col1, #T_a6c6f_row3_col2, #T_a6c6f_row3_col3, #T_a6c6f_row3_col4, #T_a6c6f_row4_col1, #T_a6c6f_row4_col2, #T_a6c6f_row4_col3, #T_a6c6f_row4_col4, #T_a6c6f_row5_col1, #T_a6c6f_row5_col2, #T_a6c6f_row5_col3, #T_a6c6f_row5_col4, #T_a6c6f_row6_col1, #T_a6c6f_row6_col2, #T_a6c6f_row6_col3, #T_a6c6f_row6_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a6c6f_row0_col2, #T_a6c6f_row0_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a6c6f_row0_col3, #T_a6c6f_row7_col0, #T_a6c6f_row7_col1, #T_a6c6f_row7_col2, #T_a6c6f_row7_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a6c6f_row1_col0, #T_a6c6f_row5_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_a6c6f_row2_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# ...
